# %% [markdown]
# <a href="https://colab.research.google.com/github/4100E020/homework/blob/main/20210915.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print("pandas version: %s" % pd.__version__)
# Out:
# pandas version: 1.1.5
